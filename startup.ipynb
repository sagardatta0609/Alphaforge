# %%
from IPython.display import HTML

html_content = '''
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
  <title>AlphaForge | Smart Waste-to-Energy Hubs</title>

  <style>
    * {
      margin: 0;
      padding: 0;
      box-sizing: border-box;
      font-family: "Segoe UI", sans-serif;
    }

    body {
      line-height: 1.6;
      color: #222;
    }

    /* HERO */
    .hero {
      background: linear-gradient(to right, #0f766e, #064e3b);
      color: white;
      padding: 2rem 5%;
      min-height: 90vh;
    }

    .navbar {
      display: flex;
      justify-content: space-between;
      align-items: center;
    }

    .logo {
      font-size: 1.8rem;
      font-weight: bold;
    }

    .hero-content {
      margin-top: 5rem;
      max-width: 700px;
    }

    .hero-content h2 {
      font-size: 2.6rem;
      margin-bottom: 1rem;
    }

    .hero-content p {
      font-size: 1.1rem;
      margin-bottom: 2rem;
    }

    .btn {
      padding: 0.7rem 1.5rem;
      background: white;
      color: #064e3b;
      text-decoration: none;
      border-radius: 6px;
      font-weight: 600;
    }

    .primary {
      background: #22c55e;
      color: #053b2f;
    }

    /* SECTIONS */
    .section {
      padding: 4rem 10%;
      text-align: center;
    }

    .light {
      background: #f8fafc;
    }

    .dark {
      background: #064e3b;
      color: white;
    }

    .section h2 {
      font-size: 2rem;
      margin-bottom: 1.5rem;
    }

    /* CARDS */
    .cards {
      display: flex;
      flex-wrap: wrap;
      gap: 1rem;
      justify-content: center;
      margin-top: 2rem;
    }

    .card {
      background: white;
      color: #064e3b;
      padding: 1.2rem 1.5rem;
      border-radius: 10px;
      min-width: 220px;
      font-weight: 600;
    }

    /* LISTS */
    .steps {
      max-width: 600px;
      margin: auto;
      text-align: left;
    }

    .steps li {
      margin-bottom: 1rem;
    }

    .impact {
      list-style: none;
      font-size: 1.1rem;
    }

    .impact li {
      margin-bottom: 0.7rem;
    }

    /* CONTACT */
    .contact p {
      margin-top: 0.7rem;
      font-size: 1.1rem;
    }

    /* FOOTER */
    footer {
      background: #022c22;
      color: white;
      text-align: center;
      padding: 1rem;
    }

    /* RESPONSIVE */
    @media (max-width: 768px) {
      .hero-content h2 {
        font-size: 2rem;
      }

      .section {
        padding: 3rem 6%;
      }
    }
  </style>
</head>

<body>

  <!-- HERO -->
  <header class="hero">
    <nav class="navbar">
      <h1 class="logo">AlphaForge</h1>
      <a href="#contact" class="btn">Get in Touch</a>
    </nav>

    <div class="hero-content">
      <h2>Powering Small Cities with Smart Waste-to-Energy Hubs</h2>
      <p>Turning organic waste into clean energy, local jobs, and healthier communities.</p>
      <a href="#solution" class="btn primary">Explore Our Solution</a>
    </div>
  </header>

  <!-- PROBLEM -->
  <section class="section light">
    <h2>The Problem</h2>
    <p>
      India generates over <strong>62 million tonnes of waste annually</strong>,
      most of it unmanaged in Tier-2 and Tier-3 cities.
      Organic waste releases methane, causing pollution,
      health risks, and wasted energy potential.
    </p>
  </section>

  <!-- SOLUTION -->
  <section id="solution" class="section dark">
    <h2>Our Solution</h2>
    <p>
      AlphaForge builds <strong>modular micro waste-to-energy hubs</strong>
      that locally convert organic kitchen and garden waste into:
    </p>

    <div class="cards">
      <div class="card">🔥 Biogas for Cooking</div>
      <div class="card">⚡ Electricity for Shops & Community Centers</div>
      <div class="card">🌱 Organic Compost for Farmers</div>
    </div>
  </section>

  <!-- HOW IT WORKS -->
  <section class="section light">
    <h2>How It Works</h2>
    <ol class="steps">
      <li>Households segregate organic waste</li>
      <li>Waste is collected locally</li>
      <li>Micro-hub processes waste using anaerobic digestion</li>
      <li>Energy & compost are reused locally</li>
    </ol>
  </section>

  <!-- IMPACT -->
  <section class="section dark">
    <h2>Why It Matters</h2>
    <ul class="impact">
      <li>♻️ Reduces landfill dumping</li>
      <li>🌫 Cuts methane emissions</li>
      <li>👷 Creates local employment</li>
      <li>🌾 Improves soil health</li>
      <li>🏘 Empowers small towns</li>
    </ul>
  </section>

  <!-- BUSINESS MODEL -->
  <section class="section light">
    <h2>Revenue Model</h2>
    <div class="cards">
      <div class="card">Biogas Subscriptions</div>
      <div class="card">Electricity Sales</div>
      <div class="card">Compost Sales</div>
      <div class="card">CSR & Municipality Partnerships</div>
      <div class="card">Carbon Credits</div>
    </div>
  </section>

  <!-- CONTACT -->
  <section id="contact" class="section dark contact">
    <h2>Let’s Build Cleaner Cities</h2>
    <p>Interested in partnerships, pilots, or investments?</p>
    <p><strong>Email:</strong> hello@alphaforge.in</p>
    <p><strong>Serving:</strong> Tier-2 & Tier-3 India</p>
  </section>

  <footer>
    <p>© 2026 AlphaForge. All rights reserved.</p>
  </footer>

</body>
</html>
'''

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#   <title>AlphaForge | Smart Waste-to-Energy Hubs</title>
#
#   <style>
#     * {
#       margin: 0;
#       padding: 0;
#       box-sizing: border-box;
#       font-family: "Segoe UI", sans-serif;
#     }
#
#     body {
#       line-height: 1.6;
#       color: #222;
#     }
#
#     /* HERO */
#     .hero {
#       background: linear-gradient(to right, #0f766e, #064e3b);
#       color: white;
#       padding: 2rem 5%;
#       min-height: 90vh;
#     }
#
#     .navbar {
#       display: flex;
#       justify-content: space-between;
#       align-items: center;
#     }
#
#     .logo {
#       font-size: 1.8rem;
#       font-weight: bold;
#     }
#
#     .hero-content {
#       margin-top: 5rem;
#       max-width: 700px;
#     }
#
#     .hero-content h2 {
#       font-size: 2.6rem;
#       margin-bottom: 1rem;
#     }
#
# ...
